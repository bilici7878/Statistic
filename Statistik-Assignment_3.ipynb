# %% [markdown]
# ### Statistik Assignment-3

# %%
from IPython.display import Image

Image(filename="Exer3.png")

# %%
import numpy as np
from scipy import stats

# %%
x = [16,15,12,15,10,16,16,15,15,15,12,18,12,14,10,18,15,14,15,15]
print(sorted(x))
len(x)
# Out:
# [10, 10, 12, 12, 12, 14, 14, 15, 15, 15, 15, 15, 15, 15, 15, 16, 16, 16, 18, 18]
# 20

# %%
print("Mean :", np.mean(x))
print("Median :",np.median(x))
print("Mode :",stats.mode(x)[0][0])
print("Std :",np.std(x))
print("Range:",np.max(x)-np.min(x))
print("Variance :", np.var(x))
# Out:
# Mean : 14.4
# Median : 15.0
# Mode : 15
# Std : 2.1540659228538015
# Range: 8
# Variance : 4.64

# %%
from IPython.display import Image

Image(filename="Exer2.png")

# %%
import numpy as np
from scipy import stats

x = [10,9,7,9,8,9,5,4]
print(sorted(x))
len(x)
# Out:
# [4, 5, 7, 8, 9, 9, 9, 10]
# 8

# %%
print("Mean :", np.mean(x))
print("Median :",np.median(x))
print("Mode :",stats.mode(x)[0][0])
print("Std :",np.std(x))
print("Range:",np.max(x)-np.min(x))
print("Variance :", np.var(x))
# Out:
# Mean : 7.625
# Median : 8.5
# Mode : 9
# Std : 1.996089927833914
# Range: 6
# Variance : 3.984375

# %%
from IPython.display import Image

Image(filename="Exer3.3.png")

# %%
import numpy as np
from scipy import stats
from scipy.stats import iqr, skew, kurtosis

salary = [120, 80, 85, 85, 80, 83, 100, 105, 105, 85, 75, 125, 120, 105, 85, 80, 95, 90, 95, 85, 80, 85, 120, 100, 105, 90]
print(sorted(salary))
len(salary)
# Out:
# [75, 80, 80, 80, 80, 83, 85, 85, 85, 85, 85, 85, 90, 90, 95, 95, 100, 100, 105, 105, 105, 105, 120, 120, 120, 125]
# 26

# %%
print("Mean :", np.mean(salary))
print("Median :",np.median(salary))
print("Mode :",stats.mode(salary)[0][0])
print("Std :",np.std(salary))
print("Range :",np.max(salary)-np.min(salary))
print("IQR :",stats.iqr(salary))
print("Variance :", np.var(salary))
# Out:
# Mean : 94.73076923076923
# Median : 90.0
# Mode : 85
# Std : 14.300504811712853
# Range : 50
# IQR : 20.0
# Variance : 204.50443786982248
